# %%
import matplotlib.pyplot as plt

# Data from the table for jurors' opinions on whether they had enough chance to express their opinions
opinion_labels = ['Disagree', 'Neutral', 'Agree', 'Strongly agree']
opinion_counts = [0, 0, 109, 126]  # Unweighted frequency for the available data
missing_data = 2707  # Blank (BLNK) responses to be noted in the visualization
additional_missing = 7898  # Additional missing responses (.M)

# Since we have values with 0 responses, it's better to visualize the data using a bar chart
# Creating a bar chart with light blue bars
plt.figure(figsize=(10, 6))
bars = plt.bar(opinion_labels, opinion_counts, color='lightblue')

# Adding the count above the bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 1, round(yval, 1), ha='center', va='bottom')

# Adding a note about the missing and blank data
plt.text(1, max(opinion_counts) / 2, f'Blank Data: {missing_data}', fontsize=12, ha='center', color='red')
plt.text(1, max(opinion_counts) / 4, f'Additional Missing Data: {additional_missing}', fontsize=12, ha='center', color='red')

# Title and labels
plt.title('Juror Opinions on Having Enough Chance to Express Opinions')
plt.xlabel('Opinion')
plt.ylabel('Number of Responses')

# Show the bar chart
plt.tight_layout()
plt.show()

# %%
# Data from the table for serving on a criminal jury
jury_service_frequency = ['Never', 'Once', 'Twice', 'Three times', 'Four times', 'Five or more times']
jury_service_counts = [3704, 1130, 254, 83, 31, 9]  # Unweighted frequency
missing_data = 5634  # To be noted in the visualization

# Creating a bar chart with light blue bars
plt.figure(figsize=(10, 6))
bars = plt.bar(jury_service_frequency, jury_service_counts, color='lightblue')

# Adding the count above the bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 10, round(yval, 1), ha='center', va='bottom')

# Adding a note about the missing data
plt.text(2.5, max(jury_service_counts) / 2, f'Missing Data: {missing_data}', fontsize=12, ha='center', color='red')

# Title and labels
plt.title('Frequency of Serving on a Criminal Jury')
plt.xlabel('Number of Times Served')
plt.ylabel('Number of Respondents')

# Show the bar chart
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data from the table
report_frequency = ['Never', 'Once', 'Twice', 'Three times', 'Four times', 'Five or more times']
frequency_counts = [1508, 1684, 1056, 563, 279, 209]  # Unweighted frequency
missing_data = 5546  # To be noted in the visualization

# Creating a bar chart
plt.figure(figsize=(10, 6))
bars = plt.bar(report_frequency, frequency_counts, color='skyblue')

# Adding the count above the bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 50, round(yval, 1), ha='center', va='bottom')

# Adding a note about the missing data
plt.text(2.5, max(frequency_counts) / 2, f'Missing Data: {missing_data}', fontsize=12, ha='center', color='red')

# Title and labels
plt.title('Report Frequency of Survey Respondents')
plt.xlabel('Number of Times Reported')
plt.ylabel('Number of Respondents')

# Show the bar chart
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data from the table
report_frequency = ['Never', 'Once', 'Twice', 'Three times', 'Four times', 'Five or more times']
frequency_counts = [1508, 1684, 1056, 563, 279, 209]  # Unweighted frequency
missing_data = 5546  # To be noted in the visualization

# Creating a bar chart
plt.figure(figsize=(10, 6))
bars = plt.bar(report_frequency, frequency_counts, color='skyblue')

# Adding the count above the bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 50, round(yval, 1), ha='center', va='bottom')

# Adding a note about the missing data
plt.text(2.5, max(frequency_counts) / 2, f'Missing Data: {missing_data}', fontsize=12, ha='center', color='red')

# Title and labels
plt.title('Report Frequency of Survey Respondents')
plt.xlabel('Number of Times Reported')
plt.ylabel('Number of Respondents')

# Show the bar chart
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data from the table
labels = ['Low', 'Medium', 'High', 'Undocumented Code', 'Undocumented Code', 'Missing']
sizes = [1874, 3989, 580, 1, 270, 4131]  # Unweighted frequency
colors = ['#ff9999','#66b3ff','#99ff99','#c2c2f0','#ffb3e6', '#d9d9d9']  # Assign different colors
explode = (0.1, 0, 0, 0, 0, 0)  # Only "explode" the 1st slice (i.e. 'Low')

# Plot
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# Display the pie chart
plt.title('Activity Level of Adult Friends in Politics or Community Affairs')
plt.show()

# %%
# Data from the table for willingness to report to jury duty in the future
willingness_labels = ['Strongly disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly agree']
willingness_counts = [40, 73, 271, 1616, 1152]  # Unweighted frequency for the available data
missing_data = 71  # Blank (BLNK) responses to be noted in the visualization
additional_missing = 7622  # Additional missing responses (.M)

# Creating a bar chart with light blue bars
plt.figure(figsize=(10, 6))
bars = plt.bar(willingness_labels, willingness_counts, color='lightblue')

# Adding the count above the bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 10, round(yval, 1), ha='center', va='bottom')

# Adding a note about the missing and blank data
plt.text(2, max(willingness_counts) / 2, f'Blank Data: {missing_data}', fontsize=12, ha='center', color='red')
plt.text(2, max(willingness_counts) / 4, f'Additional Missing Data: {additional_missing}', fontsize=12, ha='center', color='red')

# Title and labels
plt.title('Willingness to Report to Jury Duty in the Future')
plt.xlabel('Level of Willingness')
plt.ylabel('Number of Responses')

# Show the bar chart
plt.tight_layout()
plt.show()

# %%
# Data from the table for opinions on the civil jury system as a way to settle civil lawsuits
opinion_labels = ['Strongly disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly agree']
opinion_counts = [27, 299, 672, 1774, 241]  # Unweighted frequency for the available data
missing_data = 6  # Blank (BLNK) responses to be noted in the visualization
additional_missing = 7826  # Additional missing responses (.M)

# Creating a bar chart with light blue bars
plt.figure(figsize=(10, 6))
bars = plt.bar(opinion_labels, opinion_counts, color='lightblue')

# Adding the count above the bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 10, round(yval, 1), ha='center', va='bottom')

# Adding a note about the missing and blank data
plt.text(2, max(opinion_counts) / 2, f'Blank Data: {missing_data}', fontsize=12, ha='center', color='red')
plt.text(2, max(opinion_counts) / 4, f'Additional Missing Data: {additional_missing}', fontsize=12, ha='center', color='red')

# Title and labels
plt.title('Opinions on the Civil Jury System for Settling Lawsuits')
plt.xlabel('Opinion')
plt.ylabel('Number of Responses')

# Show the bar chart
plt.tight_layout()
plt.show()

# %%
# Data from the table for attitudes towards civic responsibilities
attitude_labels = ['Strongly disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly agree']
attitude_counts = [8, 47, 347, 1878, 731]  # Unweighted frequency for the available data
missing_data = 7  # Blank (BLNK) responses to be noted in the visualization
additional_missing = 7827  # Additional missing responses (.M)

# Creating a bar chart with light blue bars
plt.figure(figsize=(10, 6))
bars = plt.bar(attitude_labels, attitude_counts, color='lightblue')

# Adding the count above the bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 10, round(yval, 1), ha='center', va='bottom')

# Adding a note about the missing and blank data
plt.text(2, max(attitude_counts) / 2, f'Blank Data: {missing_data}', fontsize=12, ha='center', color='red')
plt.text(2, max(attitude_counts) / 4, f'Additional Missing Data: {additional_missing}', fontsize=12, ha='center', color='red')

# Title and labels
plt.title('Civic Responsibility Attitude of Survey Respondents')
plt.xlabel('Attitude')
plt.ylabel('Number of Responses')

# Show the bar chart
plt.tight_layout()
plt.show()

# %%
# Data from the table for frequency of learning about politics from TV news programs
frequency_labels = ['Never', 'Less than once a week', 'Once or twice a week', 'Nearly every day', 'Every day']
frequency_counts = [209, 498, 695, 964, 589]  # Unweighted frequency for the available data
missing_data_BLNK = 6  # Blank (BLNK) responses to be noted in the visualization
missing_data_DK = 12  # 'Don't Know' (DK) responses to be noted
additional_missing = 7872  # Additional missing responses (.M)

# Creating a bar chart with light blue bars
plt.figure(figsize=(10, 6))
bars = plt.bar(frequency_labels, frequency_counts, color='lightblue')

# Adding the count above the bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 10, round(yval, 1), ha='center', va='bottom')

# Adding notes about the missing data
plt.text(2, max(frequency_counts) / 2, f'Blank Data: {missing_data_BLNK}', fontsize=12, ha='center', color='red')
plt.text(2, max(frequency_counts) / 4, f'Don\'t Know: {missing_data_DK}', fontsize=12, ha='center', color='red')
plt.text(2, max(frequency_counts) / 8, f'Additional Missing Data: {additional_missing}', fontsize=12, ha='center', color='red')

# Title and labels
plt.title('Frequency of Learning About Politics from TV News')
plt.xlabel('Frequency')
plt.ylabel('Number of Responses')

# Show the bar chart
plt.tight_layout()
plt.show()
